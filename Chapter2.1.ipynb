# %%
"""
Bài 1. Viết chương trình nhập vào một chuỗi
Xuất ra màn hình chuỗi ký tự hoa
Xuất ra màn hình chuỗi ký tự có ký tự đầu là ký tự hoa
Xuất ra màn hình chuỗi ký tự thường
"""

# %%
st = input("Enter your string:")
st_upper = st.upper()
st_lower = st.lower()
st_title = st.title()

print("A Upper String is: " + st_upper)
print("A Lower String is : " + st_lower)
print("A Title String is : " + st_title)

# %%
'''
Bài 2. Cho chuỗi biểu diễn địa chỉ email:   " minhnhutvh@gmail.com" 
Rút trích và hiển thị chuỗi "gmail.com" (Đây chính là  tên Host)
'''

# %%
data = "minhnhutvh@gmail.com"
position = data.find("@")               
host = data[position +1 :]
print(host)

# %%
'''
Bài 3. Cho chuỗi biểu diễn:  
        ‘minhnhutvh@gmai.com Sat Jan 5 09:14:16’
Rút trích và hiển thị chuỗi “gmail.com”
'''

# %%
data = "minhnhutvh@gmail.com Sat Jan 5 09:14:16"
Start_position = data.find("@")                #  10
End_position = data.find(" ", Start_position)  #  26
host = data[Start_position +1 : End_position]
print(host)

# %%
''' Bài 4: Viết một chương trình thay thế một từ trong chuỗi. Yêu cầu: 
Nhập vào một chuỗi 
Nhập vào một từ cần thay thế và một từ thay thế. 
Sau đó, hiển thị kết quả ra màn hình.'''

# %%
st1 = input("Enter your string: ")
st2 = input(" Enter the word that needs to replace: ")
st3 = input(" Enter the word after being replaced: ")

st1 = st1.replace(st2,st3)
print(st1)

# %%
'''Bài 5: Viết một chương trình nhập vào 1 chuỗi. Sau đó, xuất ra màn hình: 
5 ký tự cuối cùng; 5 ký tự đầu tiên. 
4 chuỗi trên một dòng cách 1 khoảng trắng.
4 chuỗi trên 4 dòng.
'''

# %%
st = input("Enter your string: ")
First_five_characters = st[:5]
Last_five_characters = st[len(st)-5:]
Str_1_line = 4 * (st + " ")
Str_4_line = 4 * (st + "\n")

print("First five characters are: " + First_five_characters)
print("Last five characters are: " + Last_five_characters)
print("Four strings of one line are: " + Str_1_line)
print("Four strings of four line are: \n" + Str_4_line)

# %%
'''Bài 6: Viết chương trình tính thể tích hình trụ V = πr2h với r là bán kính của mặt đáy,
 h là chiều cao của hình trụ, và π là hằng số pi. 
 Với r và h nhập vào từ bàn phím.
'''

# %%
from math import pi
R = input("Enter the radius: ")
H = input("Enter the height: ")
V = pi * float(R)**2 * float(H)

print("Thể tích hình trụ là:" + str(V))

# %%
'''Bài 7: Viết chương trình tính diện tích tam giác theo công thức. Yêu cầu nhập vào 3 cạnh và các góc A,B và C (radian)
'''

# %%
from math import sin, radians, pi

a = float(input("Nhập cạnh a: "))
b = float(input("Nhập cạnh b: "))
c = float(input("Nhập cạnh c: "))
A = radians(float(input("Nhập góc A (độ): ")))
B = radians(float(input("Nhập góc B (độ): ")))
C = radians(float(input("Nhập góc C (độ): ")))

if (a + b > c and a + c > b and b + c > a):
    # Tổng ba góc phải xấp xỉ 180 độ
    if abs(A + B + C - pi) < 0.001: 
        S = 0.5 * a * b * sin(C)
        print("Diện tích tam giác là:", S)
    else:
        print("Ba góc không tạo thành một tam giác.")
else:
    print("Ba cạnh a, b, c không thể tạo thành một tam giác.")

# %%
'''Bài 8: Viết chương trình tính diện tích tam giác đều theo định lý Heron. Yêu cầu nhập vào cạnh tam giác đều.'''

# %%
from math import sqrt
print("Nhập độ dài ba cạnh của tam giác đều:")
a,b,c = float(input("Nhập canh a")), float(input("Nhập canh b")), float(input("Nhập canh c"))
if (a==b==c):
    S=a**2*sqrt(3)/4
    print("Diện tích tam giác đều là:", S)
else:
    print("Ba cạnh không tạo thành tam giác đều.")

# %%
'''Bài 9: Chạy chương trình Bài 7, nhập giá trị cho trường hợp tam giác đều 
(lưu ý: giá trị cạnh tam giác = giá trị cạnh tam giác Bài 8). 
Đánh giá kết quả khi chạy chương trình Bài 7 và Bài 8
'''

# %%
from math import sin, radians, pi

a = float(input("Nhập cạnh a: "))
b = float(input("Nhập cạnh b: "))
c = float(input("Nhập cạnh c: "))
A = radians(float(input("Nhập góc A (độ): ")))
B = radians(float(input("Nhập góc B (độ): ")))
C = radians(float(input("Nhập góc C (độ): ")))

if (a + b > c and a + c > b and b + c > a):
    # Tổng ba góc phải xấp xỉ 180 độ
    if abs(A + B + C - pi) < 0.001: 
        S = 0.5 * a * b * sin(C)
        print("Diện tích tam giác là:", S)
    else:
        print("Ba góc không tạo thành một tam giác.")
else:
    print("Ba cạnh a, b, c không thể tạo thành một tam giác.")

# %% [markdown]
# Kết quả khi chạy chương trình bày 7 (cho trường hợp tam giác đều) và bài 8 là bằng nhau (Cạnh = 6, góc = 60)

# %%
'''Bài 10: Viết chương trình yêu cầu người dùng nhập chiều rộng và chiều dài của một căn phòng. 
Chiều dài và chiều rộng sẽ hiển thị kiểu số dấu phẩy động. Hiển thị diện tích căn phòng. 
'''

# %%
chieu_dai = float(input("Nhập chiều dài của căn phòng (m): "))
chieu_rong = float(input("Nhập chiều rộng của căn phòng (m): "))

# Tính diện tích
dien_tich = chieu_dai * chieu_rong

# Hiển thị kết quả
print(f"Diện tích căn phòng là: {dien_tich:.2f} mét vuông")

# %%
'''Bài 11: Viết chương trình đọc chiều dài và chiều rộng của một cánh đồng từ người dùng. 
Hiển thị diện tích của cánh đồng theo theo đơn vị tính là Mẫu Anh.
 Gợi ý: Một Mẫu Anh bằng 43.560 met vuông.'''

# %%
# Nhập chiều dài và chiều rộng (mét)
dai = float(input("Nhập chiều dài của cánh đồng (m): "))
rong = float(input("Nhập chiều rộng của cánh đồng (m): "))

# Tính diện tích mét vuông
dien_tich_m2 = dai * rong

# Đổi sang mẫu Anh (1 mẫu Anh = 43,560 m2)
dien_tich_mau_anh = dien_tich_m2 / 43560

# Hiển thị kết quả
print(f"Diện tích cánh đồng là: {dien_tich_mau_anh:.2f} mẫu Anh")

# %%
'''Bài 12: Viết chương trình nhập chi phí của một bữa ăn tại nhà hàng từ người dùng. 
Chương trình sẽ tính thuế và tiền boa cho bữa ăn. 
Trong đó, tiền boa là 18% số tiền bữa ăn (không có thuế); tiền thuế là 5% số tiền bữa ăn.
Đầu ra của chương trình là tổng tiền, gồm: thuế, số tiền boa và tiền bữa ăn. 
Định dạng đầu ra sao cho tất cả các giá trị được hiển thị bằng hai con số thập phân
'''

# %%
# Nhập chi phí bữa ăn
expense = float(input("Nhập chi phí bữa ăn tại nhà hàng:"))
tax = expense * 0.05
tip = expense * 0.18

total = expense + tax + tip
print(f"Tổng tiền bao gồm thuế và tiền boa là: {total:.2f}")
# Out:
# Tổng tiền bao gồm thuế và tiền boa là: 399.75

# %%
'''Bài 13: Viết chương trình đọc một số nguyên dương n từ người dùng và sau đó hiển thị tổng của tất cả các số nguyên từ 1 đến n.
 Tổng của n số nguyên dương đầu tiên có thể được tính bằng công thức:
S = n(n + 1) / 2
'''

# %%
# Nhập số nguyên dương n
n = int(input("Nhập một số nguyên dương n: "))
# Tính tổng S
S = n*(n+1)/2
print(f"Tổng của các số nguyên từ 1 đến {n} là: {S}")
# Out:
# Tổng của các số nguyên từ 1 đến 5 là: 15.0

# %%
'''Bài 14: Viết một chương trình đọc hai số nguyên a và b từ người dùng. 
Chương trình sẽ tính toán và hiển thị:
Tổng của a và b
Hiệu của a và b
Tích của a và b
Thương của a chia cho b
Phần còn lại khi a được chia cho b
Kết quả của 〖𝑙𝑜𝑔〗_10 𝑎
Kết quả của a^^b
'''

# %%
from math import log10
# Nhập 2 số nguyên a và b
a, b = int(input("Nhập số nguyên a: ")), int(input("Nhập số nguyên b: "))
print(f"Tổng của a và b là: {a + b}")
print(f"Hiệu của a và b là: {a - b}")
print(f"Tích của a và b là: {a * b}")   
print(f"Thương của a chia cho b là: {a / b}")
print(f"Phần còn lại khi a được chia cho b là: {a % b}")
print(f"Kết quả của log_10 a là: {log10(a)}")
print(f"Kết quả của a^b là: {a ** b}")
# Out:
# Tổng của a và b là: 31
# Hiệu của a và b là: -11
# Tích của a và b là: 210
# Thương của a chia cho b là: 0.47619047619047616
# Phần còn lại khi a được chia cho b là: 10
# Kết quả của log_10 a là: 1.0
# Kết quả của a^b là: 1000000000000000000000

# %%
'''Bài 15: Năng lượng Q cần để thay đổi ΔT nhiệt độ (xét trường hợp ΔT > 0) của M gram nước được tính bằng: Q = M × C × ΔT, trong đó ΔT có đơn vị là độ (độ Celsius), M có đơn vị gram và Q có đơn vị là Joules.  
Viết chương trình theo yêu cầu:
Đọc khối lượng của nước và sự thay đổi ΔT nhiệt độ từ người dùng. Chương trình sẽ hiển thị tổng năng lượng của nước khi thay đổi nhiệt độ mong muốn. 
Gợi ý: Nhiệt dung riêng của nước là 4.186 J/g◦C.
Tính toán chi phí khi thay đổi ΔT nhiệt độ của nước, biết rằng: chi phí là 8,9 cent mỗi kilowatt giờ, 1 Joules = 2.777e-7 kWh.  Hãy tính chi phí để nước đạt nhiệt độ như yêu cầu.
'''

# %%
# Nhập Khôi lượng nước (gram) và sự thay đổi nhiệt độ (độ C)
M, delta_T = float(input("Nhập khối lượng nước (gram): ")), float(input("Nhập sự thay đổi nhiệt độ (độ C): "))
C = 4.186  # Nhiệt dung riêng của nước (J/g°C)
Q = M*C*delta_T  # Năng lượng cần thiết (Joules)
print(f"Năng lượng cần thiết để thay đổi nhiệt độ là: {Q:.2f} Joules")

# Tính chi phí (cent)
cost_per_kWh = 8.9  # cent
cost = Q * 2.777e-7 * cost_per_kWh
print(f"Chi phí để thay đổi nhiệt độ là: {cost:.4f} cent")
# Out:
# Năng lượng cần thiết để thay đổi nhiệt độ là: 146.51 Joules
# Chi phí để thay đổi nhiệt độ là: 0.0004 cent

# %%
'''Bài 16: Viết một chương trình xác định tốc độ di chuyển của một vật khi nó chạm đất.
 Người dùng sẽ nhập chiều cao mà từ đó vật đó được thả (đơn vị tính mét (m)).
 Gợi ý: Sử dụng công thức 𝒗_𝒇  =√(𝒗_𝒊^𝟐  + 𝟐𝐚𝐝)  để tính tốc độ cuối cùng,
   𝒗_𝒊  tốc độ ban đầu, a là gia tốc trọng trường, và d là độ cao. 
   Tốc độ ban đầu của một vật là 0 m/s,  gia tốc trọng trường là 9,8 m/s2.
'''

# %%
from math import sqrt
# Nhập chiều cao (mét)
d = float(input("Nhập chiều cao (mét): "))
a = 9.8  # Gia tốc trọng trường (m/s^2)
v_i = 0  # Tốc độ ban đầu (m/s)
v_f = sqrt(v_i**2 + 2*a*d)  # Tính tốc độ cuối cùng (m/s)
print(f"Tốc độ của vật khi chạm đất là: {v_f:.2f} m/s")
# Out:
# Tốc độ của vật khi chạm đất là: 23.00 m/s

# %%
'''Bài 17: Khi gió thổi trong thời tiết lạnh, làm cho không khí lạnh hơn so với thực tế. 
Nguyên nhân là do sự chuyển động của không khí làm tăng tốc độ làm mát cho các vật thể (chẳng hạn, như con người).
Năm 2001, Canada, Vương quốc Anh và Hoa Kỳ đã áp dụng công thức sau đây để tính toán chỉ số gió lạnh: WCI = 13,12 + 0,6215Ta - 11,37V0.16 + 0,3965Ta V0.16
Trong công thức Ta là nhiệt độ không khí tính bằng độ C và V là tốc độ gió tính bằng km/giờ.
Viết chương trình đọc nhiệt độ không khí và tốc độ gió từ người dùng. Hiển thị chỉ số gió lạnh được làm tròn đến số nguyên gần nhất.
'''

# %%
try:
    Ta = float(input("Nhập nhiệt độ không khí (độ C): "))
except ValueError:
    print("Nhiệt độ không hợp lệ. Vui lòng nhập một số.")
    exit()

# Yêu cầu người dùng nhập tốc độ gió V (km/giờ)
try:
    V = float(input("Nhập tốc độ gió (km/giờ): "))
except ValueError:
    print("Tốc độ gió không hợp lệ. Vui lòng nhập một số.")
    exit()

WCI = 13.12 + 0.6215 * Ta - 11.37 * (V ** 0.16) + 0.3965 * Ta * (V ** 0.16)

# Làm tròn chỉ số gió lạnh đến số nguyên gần nhất
# Sử dụng hàm round() của Python để làm tròn
WCI_rounded = round(WCI)

# Hiển thị kết quả cho người dùng
print(f"Chỉ số gió lạnh (WCI) là: {WCI_rounded} độ C")
# Out:
# Chỉ số gió lạnh (WCI) là: 42 độ C
